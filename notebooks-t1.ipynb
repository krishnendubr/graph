# %%
# !pip install dash plotly jupyter-dash
# run only once to install libraries

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from jupyter_dash import JupyterDash
from dash import dcc, html, Input, Output

# ------------------------
# Load CSV safely
# ------------------------
def load_file(filename):
    return pd.read_csv(filename, encoding="utf-8-sig", on_bad_lines="skip")

results_df = load_file("results.csv")
limits_df  = load_file("limits.csv")

results_df.columns = results_df.columns.str.strip().str.lower()
limits_df.columns  = limits_df.columns.str.strip()

# ------------------------
# Prepare parameters
# ------------------------
parameters = limits_df["param_name"].unique()

# Merge limits
merged = results_df.merge(
    limits_df[["param_name", "Lower OK", "Upper OK"]],
    on="param_name",
    how="left"
)

merged["out_of_spec"] = (
    (merged["result"] < merged["Lower OK"]) |
    (merged["result"] > merged["Upper OK"])
)

# ------------------------
# JupyterDash App
# ------------------------
app = JupyterDash(__name__)

app.layout = html.Div(
    style={"padding": "10px"},
    children=[
        html.H2("Process Monitoring Interactive Dashboard"),

        dcc.Dropdown(
            id="param-select",
            options=[{"label": p, "value": p} for p in parameters],
            value=list(parameters),
            multi=True
        ),

        dcc.Graph(id="process-graph", style={"height": "85vh"})
    ]
)

# ------------------------
# Callback
# ------------------------
@app.callback(
    Output("process-graph", "figure"),
    Input("param-select", "value")
)
def update_graph(selected_params):

    if not selected_params:
        return go.Figure()

    fig = make_subplots(
        rows=len(selected_params),
        cols=1,
        shared_xaxes=True,
        vertical_spacing=0.03,
        subplot_titles=selected_params
    )

    for i, param in enumerate(selected_params, start=1):
        data = merged[merged["param_name"] == param].reset_index(drop=True)

        low  = data["Lower OK"].iloc[0]
        high = data["Upper OK"].iloc[0]

        fig.add_trace(
            go.Scatter(
                x=data.index,
                y=data["result"],
                mode="lines+markers",
                name=f"{param} Result",
                customdata=data["uniquepart_id"],
                hovertemplate="Part: %{customdata}<br>Value: %{y}<extra></extra>"
            ),
            row=i, col=1
        )

        oos = data[data["out_of_spec"]]
        fig.add_trace(
            go.Scatter(
                x=oos.index,
                y=oos["result"],
                mode="markers",
                marker=dict(color="red", size=8),
                name="Out of Spec",
                showlegend=(i == 1),
                customdata=oos["uniquepart_id"],
                hovertemplate="Part: %{customdata}<br>OOS: %{y}<extra></extra>"
            ),
            row=i, col=1
        )

        fig.add_hline(y=high, line_dash="dash", line_color="red", row=i, col=1)
        fig.add_hline(y=low,  line_dash="dash", line_color="green", row=i, col=1)

        fig.add_hrect(
            y0=low,
            y1=high,
            fillcolor="green",
            opacity=0.1,
            line_width=0,
            row=i, col=1
        )

    fig.update_layout(
        height=300 * len(selected_params),
        hovermode="x unified",
        showlegend=True
    )

    return fig

# ------------------------
# RUN APP INSIDE NOTEBOOK
# ------------------------
app.run(mode="inline", debug=True)
# Out:
# C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages\dash\dash.py:644: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
pip install "dash[cloud]"
# Out:
# Requirement already satisfied: dash[cloud] in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.4.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from dash[cloud]) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from dash[cloud]) (3.1.5)
# Requirement already satisfied: plotly>=5.0.0 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from dash[cloud]) (6.5.2)
# Requirement already satisfied: importlib-metadata in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from dash[cloud]) (8.7.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from dash[cloud]) (4.15.0)
# Requirement already satisfied: requests in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from dash[cloud]) (2.32.5)
# Requirement already satisfied: retrying in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from dash[cloud]) (1.4.2)
# Requirement already satisfied: nest-asyncio in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from dash[cloud]) (1.6.0)
# Requirement already satisfied: setuptools in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from dash[cloud]) (80.10.2)
# Requirement already satisfied: plotly-cloud in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from dash[cloud]) (0.1.0)
# Requirement already satisfied: blinker>=1.9.0 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from Flask<3.2,>=1.0.4->dash[cloud]) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from Flask<3.2,>=1.0.4->dash[cloud]) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from Flask<3.2,>=1.0.4->dash[cloud]) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from Flask<3.2,>=1.0.4->dash[cloud]) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from Flask<3.2,>=1.0.4->dash[cloud]) (3.0.3)
# Requirement already satisfied: colorama in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash[cloud]) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly>=5.0.0->dash[cloud]) (2.16.0)
# Requirement already satisfied: packaging in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly>=5.0.0->dash[cloud]) (26.0)
# Requirement already satisfied: zipp>=3.20 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from importlib-metadata->dash[cloud]) (3.23.0)
# Requirement already satisfied: httpx<1.0.0,>=0.24.0 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly-cloud->dash[cloud]) (0.28.1)
# Requirement already satisfied: rich>=10.0.0 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly-cloud->dash[cloud]) (14.3.2)
# Requirement already satisfied: tomli-w>=1.2.0 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly-cloud->dash[cloud]) (1.2.0)
# Requirement already satisfied: tomli>=2.2.1 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly-cloud->dash[cloud]) (2.4.0)
# Requirement already satisfied: anyio in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1.0.0,>=0.24.0->plotly-cloud->dash[cloud]) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1.0.0,>=0.24.0->plotly-cloud->dash[cloud]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1.0.0,>=0.24.0->plotly-cloud->dash[cloud]) (1.0.9)
# Requirement already satisfied: idna in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1.0.0,>=0.24.0->plotly-cloud->dash[cloud]) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.24.0->plotly-cloud->dash[cloud]) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=10.0.0->plotly-cloud->dash[cloud]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=10.0.0->plotly-cloud->dash[cloud]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.0.0->plotly-cloud->dash[cloud]) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->dash[cloud]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\soura\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->dash[cloud]) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.
